# %% [markdown]
# <h2 align="center">Spacy Tokenization</h2>

# %% [markdown]
# Cargar el corpus desde el archivo JSON:

# %%
import json

with open('recursos/corpus.json', 'r', encoding='utf-8') as file:
    corpus = json.load(file)

# %% [markdown]
# Iterar sobre el corpus y tokenizar el contenido de cada documento:

# %%
import spacy

# Cargar el modelo de spaCy en español
nlp = spacy.load("es_core_news_sm")

tokenized_corpus = []
for documento in corpus:
    doc = nlp(documento["contenido"])
    tokens = [token.text for token in doc]
    tokenized_corpus.append({
        "grado": documento["grado"],
        "materia": documento["materia"],
        "archivo": documento["archivo"],
        "tokens": tokens
    })

# %%
# import json
# Guardar el corpus tokenizado en un archivo JSON
with open('recursos/tokenized_corpus.json', 'w', encoding='utf-8') as file:
    json.dump(tokenized_corpus, file, ensure_ascii=False, indent=4)

# %%
import csv
# Guardar el corpus tokenizado en un archivo CSV
with open('recursos/tokenized_corpus.csv', 'w', encoding='utf-8', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=["grado", "materia", "archivo", "tokens"])
    writer.writeheader()
    writer.writerows(tokenized_corpus)

# %% [markdown]
# ## Explorar los tokens:

# %%
for texto in tokenized_corpus:
    print(f"Grado: {texto['grado']}, Materia: {texto['materia']}, Primeros tokens: {texto['tokens'][:5]}")

total_tokens = sum(len(texto['tokens']) for texto in tokenized_corpus)
print(f"\nTotal de tokens: {total_tokens}")

all_tokens = [token for texto in tokenized_corpus for token in texto['tokens']]
unique_tokens = set(all_tokens)
print(f"Número de tokens únicos: {len(unique_tokens)}")
# Out:
# Grado: 1er grado, Materia: ciencias_1, Primeros tokens: ['exploracion', 'de', 'la', 'naturaleza', 'y']
# Grado: 1er grado, Materia: civica_1, Primeros tokens: ['formacion', 'civica', 'y', 'etica', 'primer']
# Grado: 1er grado, Materia: español_1, Primeros tokens: ['espanol', 'libro', 'para', 'el', 'alumno']
# Grado: 1er grado, Materia: español_2, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'primer']
# Grado: 1er grado, Materia: matematicas_1, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
# Grado: 2o grado, Materia: ciencias_2, Primeros tokens: ['exploracion', 'de', 'la', 'naturaleza', 'y']
# Grado: 2o grado, Materia: civica_2, Primeros tokens: ['formacion', 'civica', 'y', 'etica', 'segundo']
# Grado: 2o grado, Materia: español_2_1, Primeros tokens: ['espanol', 'libro', 'para', 'el', 'alumno']
# Grado: 2o grado, Materia: español_2_2, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'segundo']
# Grado: 2o grado, Materia: matematicas_2, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
# Grado: 3er grado, Materia: artistica_3, Primeros tokens: ['educacion', 'artistica', 'tercer', 'grado', 'indice']
# Grado: 3er grado, Materia: ciencias_3, Primeros tokens: ['ciencias', 'naturales', 'tercer', 'grado', 'conoce']
# Grado: 3er grado, Materia: civica_3, Primeros tokens: ['formacion', 'civica', 'y', 'etica', 'tercer']
# Grado: 3er grado, Materia: español_3_1, Primeros tokens: ['espanol', 'tercer', 'grado', 'espanol', 'conoce']
# Grado: 3er grado, Materia: español_3_2, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'tercer']
# Grado: 3er grado, Materia: matematicas_3, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
# Grado: 4o grado, Materia: artistica_4, Primeros tokens: ['educacion', 'artistica', 'cuarto', 'grado', 'indice']
# Grado: 4o grado, Materia: ciencias_4, Primeros tokens: ['ciencias', 'naturales', 'cuarto', 'grado', 'conoce']
# Grado: 4o grado, Materia: constitucion_4, Primeros tokens: ['conoce', 'nuestra', 'constitucion', 'cuarto', 'grado']
# Grado: 4o grado, Materia: español_4, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'cuarto']
# Grado: 4o grado, Materia: historia_4, Primeros tokens: ['historia', 'cuarto', 'grado', 'indice', 'conoce']
# Grado: 4o grado, Materia: matematicas_4, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
# Grado: 5o grado, Materia: artistica_5, Primeros tokens: ['educacion', 'artistica', 'quinto', 'grado', 'indice']
# Grado: 5o grado, Materia: ciencias_5, Primeros tokens: ['ciencias', 'naturales', 'quinto', 'grado', 'conoce']
# Grado: 5o grado, Materia: espanol_5_1, Primeros tokens: ['espanol', 'quinto', 'grado', 'conoce', 'tu']
# Grado: 5o grado, Materia: espanol_5_2, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'quinto']
# Grado: 5o grado, Materia: historia_5, Primeros tokens: ['historia', 'quinto', 'grado', 'indice', 'conoce']
# Grado: 5o grado, Materia: matematicas_5, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
# Grado: 6o grado, Materia: artistica_6, Primeros tokens: ['educacion', 'artistica', 'sexto', 'grado', 'indice']
# Grado: 6o grado, Materia: ciencias_6, Primeros tokens: ['ciencias', 'naturales', 'sexto', 'grado', 'b']
# Grado: 6o grado, Materia: civica_6, Primeros tokens: ['formacion', 'civica', 'y', 'etica', 'sexto']
# Grado: 6o grado, Materia: espanol_6_1, Primeros tokens: ['espanol', 'sexto', 'grado', 'conoce', 'tu']
# Grado: 6o grado, Materia: espanol_6_2, Primeros tokens: ['espanol', 'libro', 'de', 'lectura', 'sexto']
# Grado: 6o grado, Materia: geografia_6, Primeros tokens: ['geografia', 'sexto', 'grado', 'conoce', 'tu']
# Grado: 6o grado, Materia: historia_6, Primeros tokens: ['historia', 'sexto', 'grado', 'indice', 'conoce']
# Grado: 6o grado, Materia: matematicas_6, Primeros tokens: ['desafios', 'matematicos', 'libro', 'para', 'el']
#
# Total de tokens: 755873
# Número de tokens únicos: 38540

# %%
# Selección de un documento del corpus (0-35)
seleccion = 0

doc = nlp(corpus[seleccion]["contenido"])
print(corpus[seleccion]["contenido"])
# Out:
# exploracion de la naturaleza y la sociedad primer grado indice presentacion conoce tu libro bloque yo el cuidado de cuerpo y vida diaria quien soy como soy y que tengo en comun con los demas como cuido cuerpo que hago en la semana como son el lugar donde vivo y otros lugares donde estan mis lugares favoritos como celebramos el inicio de la independencia de mexico que aprendi autoevaluacion evaluacion bloque soy parte de la naturaleza la naturaleza del lugar donde vivo cambios en la naturaleza del lugar donde vivo semejanzas y diferencias entre plantas y animales bene cios y riesgos de plantas y animales como celebramos el inicio de la revolucion mexicana que aprendi autoevaluacion evaluacion bloque bloque historia personal y familiar cuando cumplimos anos mis recuerdos mas importantes familia ha cambiado los juegos y juguetes de ayer y hoy nuestras costumbres y tradiciones como celebramos la promulgacion de la constitucion politica de los estados unidos mexicanos que aprendi autoevaluacion evaluacion bloque las actividades del lugar donde vivo el lugar donde vivo y sus casas actividades de las personas los horarios de trabajo y esparcimiento en el lugar donde vivo transportes del lugar donde vivo las fuentes y aplicaciones de la luz y el calor en el lugar donde vivo los objetos que usamos de que materiales estan hechos como celebramos el natalicio de benito juarez que aprendi autoevaluacion evaluacion bloque los riesgos y el cuidado del lugar donde vivo seguridad en el hogar los riesgos y las zonas del lugar donde vivo participo en el cuidado del lugar donde vivo proyecto asi es el lugar donde vivo como celebramos quienes lucharon en la batalla del cinco de mayo que aprendi autoevaluacion evaluacion bibliografia creditos iconograficos seccion recortable conoce tu libro el libro esta organizado en cinco bloques con actividades que te ayudaran a explorar observar y descubrir la naturaleza las caracteristicas de tu cuerpo y la historia del lugar donde vives puedes realizar las actividades de manera individual en equipo o en grupo en algunas es importante que participen tambien los integrantes de tu familia los trabajos finales de cada bloque presentan el siguiente orden album cartel album personal y familiar y periodico mural en el bloque realizaras un proyecto donde utilizaras lo que aprendiste durante el curso al inicio del bloque encontraras informacion de lo que realizaras durante el bloque asi como indicaciones para el trabajo final con los trabajos que realices en el bloque elaboraras un album en el que ubicaras y ordenaras acontecimientos de tu historia personal y familiar conforme sucedieron al final lo presentaras al grupo hojas de cartulina pegamento blanco lapices de colores cinta adhesiva aguja de caneva de plastico madeja de estambre materiales se menciona lo que necesitaras para realizar tu trabajo al final del bloque en cada leccion contenido el titulo de cada leccion describe lo que vas a aprender en ella preguntas al inicio de la leccion se incluyen interrogantes que te ayudaran a explorar tu conocimiento sobre los contenidos actividades que se realizaran te serviran para ampliar tus conocimientos habilidades actitudes y valores para apreciar y cuidar el lugar donde vives y reconocer la importancia de algunos acontecimientos historicos al final del bloque autoevaluacion tendras la oportunidad de reflexionar acerca de tu aprendizaje que aprendi se proporcionan indicaciones para terminar el producto de cada bloque reconoceras los conocimientos habilidades actitudes y valores que desarrollaste ademas analizaras y evaluaras los productos realizados por tus companeros para aprender de ellos evaluacion son ejercicios que al final de cada bloque integran lo que aprendiste tu libro presenta las siguientes secciones a jugar actividades en las que utilizaras tus conocimientos de manera divertida calendario senalaras la fecha conmemorativa en el dia que corresponda en el calendario asi sabras cuando se celebra ese evento hi ...

# %% [markdown]
# <h3>Utilizar el índice para capturar tokens</h3>

# %%
# Se obtiene el primer token de la
doc[0]
# Out:
# exploracion

# %%
# Se obtiene el indice 12
token = doc[12]
token.text
# Out:
# 'continentes'

# %%
# dir(token) muestra los atributos y métodos del token
dir(token)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
# type/nlp) muestra el tipo de objeto del nlp
type(nlp)
# Out:
# spacy.lang.es.Spanish

# %%
# type(doc) muestra el tipo de objeto del documento
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
# type(token) muestra el tipo de objeto del token
type(token)
# Out:
# spacy.tokens.token.Token

# %%
# nlp.pipe_names muestra los nombres de los componentes del pipeline
nlp.pipe_names
# Out:
# ['sentencizer']

# %% [markdown]
# <h3>Objeto span</h3>

# %%
span = doc[61:75]
span
# Out:
# de la independencia de mexico que aprendi autoevaluacion evaluacion bloque soy parte de la

# %%
type(span)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# <h3>Atributos de los tokens</h3>

# %%
# doc = nlp(text_cleaned)

# %%
# Aqui obtengo el segundo token de la frase (exploración) Token0
token0 = doc[1]
token0
# Out:
# de

# %%
# Es Alfabético el token0 (exploración)?
token0.is_alpha
# Out:
# True

# %%
# Es un número el token0?
token0.like_num
# Out:
# False

# %%
# Obtenemos el Token3
token3 = doc[12]
token3
# Out:
# tu

# %%
# Es un número el token3?
token3.like_num
# Out:
# False

# %%
# Es una moneda el token3?
token3.is_currency
# Out:
# False

# %%
# Obtenemos el Token4
token4 = doc[4]
token4
# Out:
# y

# %%
token4.like_num
# Out:
# False

# %%
token4.is_currency
# Out:
# False

# %%
for token in doc:
    print(token, "==>", "index: ", token.i, "is_alpha (Alfabético):", token.is_alpha, 
          ", is_punct (Puntuación):", token.is_punct, 
          ", like_num (Numero):", token.like_num,
          ", is_currency (Divisa/Moneda):", token.is_currency, "\n"
         )
# Out:
# exploracion ==> index:  0 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  1 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  2 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# naturaleza ==> index:  3 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  4 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  5 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# sociedad ==> index:  6 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# primer ==> index:  7 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# grado ==> index:  8 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# indice ==> index:  9 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# presentacion ==> index:  10 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# conoce ==> index:  11 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tu ==> index:  12 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# libro ==> index:  13 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  14 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# yo ==> index:  15 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  16 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuidado ==> index:  17 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  18 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuerpo ==> index:  19 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  20 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vida ==> index:  21 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# diaria ==> index:  22 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# quien ==> index:  23 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# soy ==> index:  24 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  25 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# soy ==> index:  26 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  27 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  28 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tengo ==> index:  29 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  30 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# comun ==> index:  31 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# con ==> index:  32 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  33 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# demas ==> index:  34 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  35 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuido ==> index:  36 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuerpo ==> index:  37 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  38 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# hago ==> index:  39 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  40 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  41 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# semana ==> index:  42 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  43 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# son ==> index:  44 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  45 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  46 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  47 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  48 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  49 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# otros ==> index:  50 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugares ==> index:  51 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  52 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# estan ==> index:  53 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mis ==> index:  54 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugares ==> index:  55 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# favoritos ==> index:  56 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  57 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# celebramos ==> index:  58 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  59 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# inicio ==> index:  60 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  61 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  62 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# independencia ==> index:  63 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  64 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mexico ==> index:  65 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  66 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aprendi ==> index:  67 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# autoevaluacion ==> index:  68 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# evaluacion ==> index:  69 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  70 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# soy ==> index:  71 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# parte ==> index:  72 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  73 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  74 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# naturaleza ==> index:  75 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  76 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# naturaleza ==> index:  77 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  78 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  79 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  80 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  81 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cambios ==> index:  82 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  83 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  84 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# naturaleza ==> index:  85 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  86 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  87 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  88 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  89 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# semejanzas ==> index:  90 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  91 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# diferencias ==> index:  92 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# entre ==> index:  93 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# plantas ==> index:  94 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  95 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# animales ==> index:  96 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bene ==> index:  97 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cios ==> index:  98 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  99 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# riesgos ==> index:  100 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  101 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# plantas ==> index:  102 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  103 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# animales ==> index:  104 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  105 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# celebramos ==> index:  106 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  107 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# inicio ==> index:  108 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  109 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  110 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# revolucion ==> index:  111 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mexicana ==> index:  112 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  113 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aprendi ==> index:  114 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# autoevaluacion ==> index:  115 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# evaluacion ==> index:  116 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  117 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  118 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# historia ==> index:  119 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# personal ==> index:  120 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  121 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# familiar ==> index:  122 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuando ==> index:  123 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cumplimos ==> index:  124 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# anos ==> index:  125 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mis ==> index:  126 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# recuerdos ==> index:  127 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mas ==> index:  128 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# importantes ==> index:  129 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# familia ==> index:  130 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# ha ==> index:  131 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cambiado ==> index:  132 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  133 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# juegos ==> index:  134 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  135 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# juguetes ==> index:  136 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  137 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# ayer ==> index:  138 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  139 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# hoy ==> index:  140 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# nuestras ==> index:  141 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# costumbres ==> index:  142 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  143 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tradiciones ==> index:  144 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  145 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# celebramos ==> index:  146 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  147 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# promulgacion ==> index:  148 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  149 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  150 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# constitucion ==> index:  151 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# politica ==> index:  152 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  153 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  154 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# estados ==> index:  155 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# unidos ==> index:  156 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mexicanos ==> index:  157 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  158 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aprendi ==> index:  159 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# autoevaluacion ==> index:  160 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# evaluacion ==> index:  161 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  162 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  163 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# actividades ==> index:  164 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  165 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  166 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  167 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  168 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  169 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  170 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  171 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  172 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  173 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# sus ==> index:  174 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# casas ==> index:  175 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# actividades ==> index:  176 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  177 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  178 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# personas ==> index:  179 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  180 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# horarios ==> index:  181 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  182 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# trabajo ==> index:  183 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  184 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# esparcimiento ==> index:  185 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  186 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  187 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  188 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  189 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  190 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# transportes ==> index:  191 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  192 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  193 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  194 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  195 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  196 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# fuentes ==> index:  197 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  198 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aplicaciones ==> index:  199 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  200 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  201 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# luz ==> index:  202 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  203 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  204 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# calor ==> index:  205 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  206 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  207 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  208 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  209 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  210 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  211 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# objetos ==> index:  212 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  213 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# usamos ==> index:  214 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  215 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  216 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# materiales ==> index:  217 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# estan ==> index:  218 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# hechos ==> index:  219 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  220 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# celebramos ==> index:  221 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  222 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# natalicio ==> index:  223 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  224 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# benito ==> index:  225 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# juarez ==> index:  226 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  227 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aprendi ==> index:  228 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# autoevaluacion ==> index:  229 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# evaluacion ==> index:  230 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  231 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  232 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# riesgos ==> index:  233 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  234 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  235 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuidado ==> index:  236 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  237 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  238 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  239 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  240 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# seguridad ==> index:  241 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  242 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  243 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# hogar ==> index:  244 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  245 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# riesgos ==> index:  246 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  247 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  248 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# zonas ==> index:  249 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  250 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  251 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  252 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  253 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# participo ==> index:  254 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  255 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  256 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuidado ==> index:  257 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  258 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  259 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  260 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  261 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# proyecto ==> index:  262 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# asi ==> index:  263 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# es ==> index:  264 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  265 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  266 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  267 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vivo ==> index:  268 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# como ==> index:  269 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# celebramos ==> index:  270 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# quienes ==> index:  271 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lucharon ==> index:  272 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  273 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  274 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# batalla ==> index:  275 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  276 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cinco ==> index:  277 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): True , is_currency (Divisa/Moneda): False
#
# de ==> index:  278 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# mayo ==> index:  279 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  280 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# aprendi ==> index:  281 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# autoevaluacion ==> index:  282 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# evaluacion ==> index:  283 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bibliografia ==> index:  284 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# creditos ==> index:  285 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# iconograficos ==> index:  286 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# seccion ==> index:  287 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# recortable ==> index:  288 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# conoce ==> index:  289 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tu ==> index:  290 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# libro ==> index:  291 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  292 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# libro ==> index:  293 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# esta ==> index:  294 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# organizado ==> index:  295 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  296 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cinco ==> index:  297 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): True , is_currency (Divisa/Moneda): False
#
# bloques ==> index:  298 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# con ==> index:  299 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# actividades ==> index:  300 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# que ==> index:  301 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# te ==> index:  302 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# ayudaran ==> index:  303 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# a ==> index:  304 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# explorar ==> index:  305 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# observar ==> index:  306 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  307 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# descubrir ==> index:  308 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  309 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# naturaleza ==> index:  310 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  311 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# caracteristicas ==> index:  312 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  313 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tu ==> index:  314 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cuerpo ==> index:  315 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  316 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  317 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# historia ==> index:  318 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# del ==> index:  319 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugar ==> index:  320 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# donde ==> index:  321 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# vives ==> index:  322 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# puedes ==> index:  323 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# realizar ==> index:  324 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  325 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# ...
#
# celebra ==> index:  13323 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13324 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# comienzo ==> index:  13325 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  13326 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  13327 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lucha ==> index:  13328 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# por ==> index:  13329 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  13330 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# independencia ==> index:  13331 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# demexicoelfinaldelaluchaporlaindependenciademexico ==> index:  13332 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13333 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# inicio ==> index:  13334 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  13335 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  13336 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# revolucionmexicana ==> index:  13337 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# a ==> index:  13338 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# b ==> index:  13339 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lugares ==> index:  13340 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  13341 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13342 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# puedes ==> index:  13343 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# localizar ==> index:  13344 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# grafico ==> index:  13345 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# b ==> index:  13346 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# croquis ==> index:  13347 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# a ==> index:  13348 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# esquema ==> index:  13349 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# seccion ==> index:  13350 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# recortable ==> index:  13351 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# pagina ==> index:  13352 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# para ==> index:  13353 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# jugar ==> index:  13354 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# se ==> index:  13355 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# necesita ==> index:  13356 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# un ==> index:  13357 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# dado ==> index:  13358 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  13359 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# dos ==> index:  13360 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): True , is_currency (Divisa/Moneda): False
#
# jugadores ==> index:  13361 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# por ==> index:  13362 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lo ==> index:  13363 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# menos ==> index:  13364 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  13365 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tarjetas ==> index:  13366 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# se ==> index:  13367 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# colocan ==> index:  13368 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# al ==> index:  13369 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# centro ==> index:  13370 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# con ==> index:  13371 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  13372 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# preguntas ==> index:  13373 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# hacia ==> index:  13374 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# abajo ==> index:  13375 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# por ==> index:  13376 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# turnos ==> index:  13377 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cada ==> index:  13378 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# jugador ==> index:  13379 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lanza ==> index:  13380 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13381 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# dado ==> index:  13382 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  13383 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13384 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# companero ==> index:  13385 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# toma ==> index:  13386 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# una ==> index:  13387 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tarjeta ==> index:  13388 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# lee ==> index:  13389 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  13390 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# pregunta ==> index:  13391 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# y ==> index:  13392 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# si ==> index:  13393 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# contesta ==> index:  13394 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# correctamente ==> index:  13395 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# avanzara ==> index:  13396 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  13397 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# casillas ==> index:  13398 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# indicadas ==> index:  13399 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# por ==> index:  13400 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13401 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# dado ==> index:  13402 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# en ==> index:  13403 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# este ==> index:  13404 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# nivel ==> index:  13405 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# ganara ==> index:  13406 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# el ==> index:  13407 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# primero ==> index:  13408 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): True , is_currency (Divisa/Moneda): False
#
# en ==> index:  13409 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# llegar ==> index:  13410 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# a ==> index:  13411 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# la ==> index:  13412 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# casilla ==> index:  13413 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# al ==> index:  13414 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# termino ==> index:  13415 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# de ==> index:  13416 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# cada ==> index:  13417 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# bloque ==> index:  13418 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# obtendras ==> index:  13419 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# las ==> index:  13420 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# tarjetas ==> index:  13421 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# para ==> index:  13422 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# avanzar ==> index:  13423 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# a ==> index:  13424 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# los ==> index:  13425 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# siguientes ==> index:  13426 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# niveles ==> index:  13427 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# seccion ==> index:  13428 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False
#
# recortable ==> index:  13429 is_alpha (Alfabético): True , is_punct (Puntuación): False , like_num (Numero): False , is_currency (Divisa/Moneda): False

# %% [markdown]
#  <h3>Personalización del tokenizador</h3>

# %%
# ORTH es un atributo que se utiliza para personalizar el tokenizador
from spacy.symbols import ORTH

nlp = spacy.blank("es")
# doc = nlp(text_cleaned)

# Aquí se obtiene los tokens del doc
tokens = [token.text for token in doc]
tokens
# Out:
# ['exploracion',
#  'de',
#  'la',
#  'naturaleza',
#  'y',
#  'la',
#  'sociedad',
#  'primer',
#  'grado',
#  'indice',
#  'presentacion',
#  'conoce',
#  'tu',
#  'libro',
#  'bloque',
#  'yo',
#  'el',
#  'cuidado',
#  'de',
#  'cuerpo',
#  'y',
#  'vida',
#  'diaria',
#  'quien',
#  'soy',
#  'como',
#  'soy',
#  'y',
#  'que',
#  'tengo',
#  'en',
#  'comun',
#  'con',
#  'los',
#  'demas',
#  'como',
#  'cuido',
#  'cuerpo',
#  'que',
#  'hago',
#  'en',
#  'la',
#  'semana',
#  'como',
#  'son',
#  'el',
#  'lugar',
#  'donde',
#  'vivo',
#  'y',
#  'otros',
#  'lugares',
#  'donde',
#  'estan',
#  'mis',
#  'lugares',
#  'favoritos',
#  'como',
#  'celebramos',
#  'el',
#  'inicio',
#  'de',
#  'la',
#  'independencia',
#  'de',
#  'mexico',
#  'que',
#  'aprendi',
#  'autoevaluacion',
#  'evaluacion',
#  'bloque',
#  'soy',
#  'parte',
#  'de',
#  'la',
#  'naturaleza',
#  'la',
#  'naturaleza',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'cambios',
#  'en',
#  'la',
#  'naturaleza',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'semejanzas',
#  'y',
#  'diferencias',
#  'entre',
#  'plantas',
#  'y',
#  'animales',
#  'bene',
#  'cios',
#  'y',
#  'riesgos',
#  'de',
#  'plantas',
#  'y',
#  'animales',
#  'como',
#  'celebramos',
#  'el',
#  'inicio',
#  'de',
#  'la',
#  'revolucion',
#  'mexicana',
#  'que',
#  'aprendi',
#  'autoevaluacion',
#  'evaluacion',
#  'bloque',
#  'bloque',
#  'historia',
#  'personal',
#  'y',
#  'familiar',
#  'cuando',
#  'cumplimos',
#  'anos',
#  'mis',
#  'recuerdos',
#  'mas',
#  'importantes',
#  'familia',
#  'ha',
#  'cambiado',
#  'los',
#  'juegos',
#  'y',
#  'juguetes',
#  'de',
#  'ayer',
#  'y',
#  'hoy',
#  'nuestras',
#  'costumbres',
#  'y',
#  'tradiciones',
#  'como',
#  'celebramos',
#  'la',
#  'promulgacion',
#  'de',
#  'la',
#  'constitucion',
#  'politica',
#  'de',
#  'los',
#  'estados',
#  'unidos',
#  'mexicanos',
#  'que',
#  'aprendi',
#  'autoevaluacion',
#  'evaluacion',
#  'bloque',
#  'las',
#  'actividades',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'el',
#  'lugar',
#  'donde',
#  'vivo',
#  'y',
#  'sus',
#  'casas',
#  'actividades',
#  'de',
#  'las',
#  'personas',
#  'los',
#  'horarios',
#  'de',
#  'trabajo',
#  'y',
#  'esparcimiento',
#  'en',
#  'el',
#  'lugar',
#  'donde',
#  'vivo',
#  'transportes',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'las',
#  'fuentes',
#  'y',
#  'aplicaciones',
#  'de',
#  'la',
#  'luz',
#  'y',
#  'el',
#  'calor',
#  'en',
#  'el',
#  'lugar',
#  'donde',
#  'vivo',
#  'los',
#  'objetos',
#  'que',
#  'usamos',
#  'de',
#  'que',
#  'materiales',
#  'estan',
#  'hechos',
#  'como',
#  'celebramos',
#  'el',
#  'natalicio',
#  'de',
#  'benito',
#  'juarez',
#  'que',
#  'aprendi',
#  'autoevaluacion',
#  'evaluacion',
#  'bloque',
#  'los',
#  'riesgos',
#  'y',
#  'el',
#  'cuidado',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'seguridad',
#  'en',
#  'el',
#  'hogar',
#  'los',
#  'riesgos',
#  'y',
#  'las',
#  'zonas',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'participo',
#  'en',
#  'el',
#  'cuidado',
#  'del',
#  'lugar',
#  'donde',
#  'vivo',
#  'proyecto',
#  'asi',
#  'es',
#  'el',
#  'lugar',
#  'donde',
#  'vivo',
#  'como',
#  'celebramos',
#  'quienes',
#  'lucharon',
#  'en',
#  'la',
#  'batalla',
#  'del',
#  'cinco',
#  'de',
#  'mayo',
#  'que',
#  'aprendi',
#  'autoevaluacion',
#  'evaluacion',
#  'bibliografia',
#  'creditos',
#  'iconograficos',
#  'seccion',
#  'recortable',
#  'conoce',
#  'tu',
#  'libro',
#  'el',
#  'libro',
#  'esta',
#  'organizado',
#  'en',
#  'cinco',
#  'bloques',
#  'con',
#  'actividades',
#  'que',
#  'te',
#  'ayudaran',
#  'a',
#  'explorar',
#  'observar',
#  'y',
#  'descubrir',
#  'la',
#  'naturaleza',
#  'las',
#  'caracteristicas',
#  'de',
#  'tu',
#  'cuerpo',
#  'y',
#  'la',
#  'historia',
#  'del',
#  'lugar',
#  'donde',
#  'vives',
#  'puedes',
#  'realizar',
#  'las',
#  'actividades',
#  'de',
#  'manera',
#  'individual',
#  'en',
#  'equipo',
#  'o',
#  'en',
#  'grupo',
#  'en',
#  'algunas',
#  'es',
#  'importante',
#  'que',
#  'participen',
#  'tambien',
#  'los',
#  'integrantes',
#  'de',
#  'tu',
#  'familia',
#  'los',
#  'trabajos',
#  'finales',
#  'de',
#  'cada',
#  'bloque',
#  'presentan',
#  'el',
#  'siguiente',
#  'orden',
#  'album',
#  'cartel',
#  'album',
#  'personal',
#  'y',
#  'familiar',
#  'y',
#  'periodico',
#  'mural',
#  'en',
#  'el',
#  'bloque',
#  'realizaras',
#  'un',
#  'proyecto',
#  'donde',
#  'utilizaras',
#  'lo',
#  'que',
#  'aprendiste',
#  'durante',
#  'el',
#  'curso',
#  'al',
#  'inicio',
#  'del',
#  'bloque',
#  'encontraras',
#  'informacion',
#  'de',
#  'lo',
#  'que',
#  'realizaras',
#  'durante',
#  'el',
#  'bloque',
#  'asi',
#  'como',
#  'indicaciones',
#  'para',
#  'el',
#  'trabajo',
#  'final',
#  'con',
#  'los',
#  'trabajos',
#  'que',
#  'realices',
#  'en',
#  'el',
#  'bloque',
#  'elaboraras',
#  'un',
#  'album',
#  'en',
#  'el',
#  'que',
#  'ubicaras',
#  'y',
#  'ordenaras',
#  'acontecimientos',
#  'de',
#  'tu',
#  'historia',
#  'personal',
#  'y',
#  'familiar',
#  'conforme',
#  'sucedieron',
#  'al',
#  'final',
#  'lo',
#  'presentaras',
#  'al',
#  'grupo',
#  'hojas',
#  'de',
#  'cartulina',
#  'pegamento',
#  'blanco',
#  'lapices',
#  'de',
#  'colores',
#  'cinta',
#  'adhesiva',
#  'aguja',
#  'de',
#  'caneva',
#  'de',
#  'plastico',
#  'madeja',
#  'de',
#  'estambre',
#  'materiales',
#  'se',
#  'menciona',
#  'lo',
#  'que',
#  'necesitaras',
#  'para',
#  'realizar',
#  'tu',
#  'trabajo',
#  'al',
#  'final',
#  'del',
#  'bloque',
#  'en',
#  'cada',
#  'leccion',
#  'contenido',
#  'el',
#  'titulo',
#  'de',
#  'cada',
#  'leccion',
#  'describe',
#  'lo',
#  'que',
#  'vas',
#  'a',
#  'aprender',
#  'en',
#  'ella',
#  'preguntas',
#  'al',
#  'inicio',
#  'de',
#  'la',
#  'leccion',
#  'se',
#  'incluyen',
#  'interrogantes',
#  'que',
#  'te',
#  'ayudaran',
#  'a',
#  'explorar',
#  'tu',
#  'conocimiento',
#  'sobre',
#  'los',
#  'contenidos',
#  'actividades',
#  'que',
#  'se',
#  'realizaran',
#  'te',
#  'serviran',
#  'para',
#  'ampliar',
#  'tus',
#  'conocimientos',
#  'habilidades',
#  'actitudes',
#  'y',
#  'valores',
#  'para',
#  'apreciar',
#  'y',
#  'cuidar',
#  'el',
#  'lugar',
#  'donde',
#  'vives',
#  'y',
#  'reconocer',
#  'la',
#  'importancia',
#  'de',
#  'algunos',
#  'acontecimientos',
#  'historicos',
#  'al',
#  'final',
#  'del',
#  'bloque',
#  'autoevaluacion',
#  'tendras',
#  'la',
#  'oportunidad',
#  'de',
#  'reflexionar',
#  'acerca',
#  'de',
#  'tu',
#  'aprendizaje',
#  'que',
#  'aprendi',
#  'se',
#  'proporcionan',
#  'indicaciones',
#  'para',
#  'terminar',
#  'el',
#  'producto',
#  'de',
#  'cada',
#  'bloque',
#  'reconoceras',
#  'los',
#  'conocimientos',
#  'habilidades',
#  'actitudes',
#  'y',
#  'valores',
#  'que',
#  'desarrollaste',
#  'ademas',
#  'analizaras',
#  'y',
#  'evaluaras',
#  'los',
#  'productos',
#  'realizados',
#  'por',
#  'tus',
#  'companeros',
#  'para',
#  'aprender',
#  'de',
#  'ellos',
#  'evaluacion',
#  'son',
#  'ejercicios',
#  'que',
#  'al',
#  'final',
#  'de',
#  'cada',
#  'bloque',
#  'integran',
#  'lo',
#  'que',
#  'aprendiste',
#  'tu',
#  'libro',
#  'presenta',
#  'las',
#  'siguientes',
#  'secciones',
#  'a',
#  'jugar',
#  'actividades',
#  'en',
#  'las',
#  'que',
#  'utilizaras',
#  'tus',
#  'conocimientos',
#  'de',
#  'manera',
#  'divertida',
#  'calendario',
#  'senalaras',
#  'la',
#  'fecha',
#  'conmemorativa',
#  'en',
#  'el',
#  'dia',
#  'que',
#  'corresponda',
#  'en',
#  'el',
#  'calendario',
#  'asi',
#  'sabras',
#  'cuando',
#  'se',
#  'celebra',
#  'ese',
#  'evento',
#  'historico',
#  'seccion',
#  'recortable',
#  'cuando',
#  'encuentres',
#  'el',
#  'siguiente',
#  'icono',
#  'utilizaras',
#  'el',
#  'material',
#  'recortable',
#  'ubicado',
#  'en',
#  'las',
#  'ultimas',
#  'paginas',
#  'del',
#  'libro',
#  'consulta',
#  'en',
#  'fuentes',
#  'de',
#  'informacion',
#  'donde',
#  'puedes',
#  'investigar',
#  'mas',
#  'acerca',
#  'del',
#  'contenido',
#  'es',
#  'conveniente',
#  'que',
#  'un',
#  'adulto',
#  'te',
#  'apoye',
#  'al',
#  'realizar',
#  'tus',
#  'investigaciones',
#  'como',
#  'celebramos',
#  'en',
#  'cada',
#  'bloque',
#  'reflexionaras',
#  'acerca',
#  'de',
#  'como',
#  'y',
#  'por',
#  'que',
#  'los',
#  'mexicanos',
#  'conmemoramos',
#  'y',
#  'celebramos',
#  'algunas',
#  'fechas',
#  'historicas',
#  'un',
#  'dato',
#  'interesante',
#  'informacion',
#  'relacionada',
#  'con',
#  'el',
#  'contenido',
#  'que',
#  'estas',
#  'trabajando',
#  'recuerda',
#  'que',
#  'son',
#  'recomendaciones',
#  'que',
#  'te',
#  'ayudaran',
#  'a',
#  'cuidar',
#  'tu',
#  'salud',
#  'y',
#  'el',
#  'ambiente',
#  'baul',
#  'informacion',
#  'que',
#  'te',
#  'ayudara',
#  'a',
#  'complementar',
#  'lo',
#  'que',
#  'aprenderas',
#  'en',
#  'cada',
#  'bloque',
#  'de',
#  'estudio',
#  'bloq',
#  'bloque',
#  'yo',
#  'el',
#  'cuidado',
#  'de',
#  'cuerpo',
#  'y',
#  'vida',
#  'diaria',
#  'para',
#  'organizar',
#  'tus',
#  'trabajos',
#  'en',
#  'este',
#  'bloque',
#  'elabora',
#  'un',
#  'album',
#  'de',
#  'la',
#  'siguiente',
#  'manera',
#  'construye',
#  'un',
#  'album',
#  'con',
#  'hojas',
#  'tamano',
#  'carta',
#  'y',
#  'coloca',
#  'los',
#  'cartones',
#  'como',
#  'pastas',
#  'con',
#  'aguja',
#  'y',
#  'estambre',
#  'cose',
#  'tu',
#  'album',
#  'para',
#  'hacer',
#  'las',
#  'estampas',
#  'divide',
#  'una',
#  'hoja',
#  'tamano',
#  'carta',
#  'en',
#  'cuatro',
#  'partes',
#  'y',
#  'recortala',
#  'de',
#  'una',
#  'hoja',
#  'obtendras',
#  'cuatro',
#  'estampas',
#  'hojas',
#  'blancas',
#  'tamano',
#  'carta',
#  'dos',
#  'cartones',
#  'del',
#  'tamano',
#  'de',
#  'una',
#  'hoja',
#  'carta',
#  'pegamento',
#  'blanco',
#  'tijeras',
#  'de',
#  'punta',
#  'roma',
#  'madeja',
#  'de',
#  'estambre',
#  'aguja',
#  'de',
#  'caneva',
#  'de',
#  'plastico',
#  'tu',
#  'nombre',
#  'edad',
#  'y',
#  'gustos',
#  'son',
#  'caracteristicas',
#  'que',
#  'te',
#  'hacen',
#  'diferente',
#  'a',
#  'los',
#  'demas',
#  'bloque',
#  'quien',
#  'soy',
#  'cuales',
#  'son',
#  'las',
#  'caracteristicas',
#  'que',
#  'te',
#  'distinguen',
#  'de',
#  'los',
#  'demas',
#  'al',
#  'descubrir',
#  'mas',
#  'de',
#  'ti',
#  'lo',
#  'sabras',
#  'nombre',
#  'es',
#  'mateo',
#  'me',
#  'gusta',
#  'el',
#  'futbol',
#  'oir',
#  'musica',
#  'y',
#  'cantar',
#  'vivo',
#  'con',
#  'papa',
#  'mama',
#  'y',
#  'hermano',
#  'carlos',
#  'hace',
#  'poco',
#  'nos',
#  'mudamos',
#  'de',
#  'monterrey',
#  'nuevo',
#  'leon',
#  'a',
#  'tuxpan',
#  'veracruz',
#  'nombre',
#  'es',
#  'sara',
#  'me',
#  'gusta',
#  'leer',
#  'observar',
#  'las',
#  'estrellas',
#  'y',
#  'andar',
#  'en',
#  'bicicleta',
#  'desde',
#  'que',
#  'recuerdo',
#  'vivo',
#  'con',
#  'mis',
#  'abuelitos',
#  'en',
#  'tuxpan',
#  'veracruz',
#  'mateo',
#  'y',
#  'sara',
#  'se',
#  'conocieron',
#  'en',
#  'la',
#  'escuela',
#  'presentate',
#  'con',
#  'un',
#  'companero',
#  'describe',
#  'a',
#  'tu',
#  'familia',
#  'la',
#  'lengua',
#  'que',
#  'habla',
#  'platica',
#  'de',
#  'la',
#  'comida',
#  'que',
#  'mas',
#  'te',
#  'gusta',
#  'de',
#  'tus',
#  'juegos',
#  'favoritos',
#  'y',
#  'si',
#  'tienes',
#  'mascota',
#  'despues',
#  'el',
#  'se',
#  'presentara',
#  'contigo',
#  'al',
#  'terminar',
#  'informa',
#  'al',
#  'resto',
#  'del',
#  'grupo',
#  'lo',
#  'que',
#  'sabes',
#  'de',
#  'tu',
#  'companero',
#  'haz',
#  'un',
#  'dibujo',
#  'de',
#  'ti',
#  'mismo',
#  'escribe',
#  'tu',
#  'nombre',
#  'y',
#  'tu',
#  'edad',
#  'y',
#  'agrega',
#  'las',
#  'cosas',
#  'que',
#  'te',
#  'gustan',
#  'pegala',
#  'en',
#  'tu',
#  'album',
#  'conocerte',
#  'y',
#  'saber',
#  'como',
#  'son',
#  'tus',
#  'companeros',
#  'te',
#  'ayuda',
#  'a',
#  'respetarlos',
#  'y',
#  'valorarlos',
#  'como',
#  'soy',
#  ...]

# %% [markdown]
# <h3>Tokenización o segmentación de frases</h3>

# %%
nlp.pipeline
# Out:
# []

# %%
# nlp.add_pipe('sentencizer') se agrega un componente al pipeline para poder segmentar las frases
try:
    nlp.add_pipe('sentencizer')
except ValueError:
    print("El componente ya está en el pipeline")

# %%
for token in doc:
    print(token)
# Out:
# exploracion
# de
# la
# naturaleza
# y
# la
# sociedad
# primer
# grado
# indice
# presentacion
# conoce
# tu
# libro
# bloque
# yo
# el
# cuidado
# de
# cuerpo
# y
# vida
# diaria
# quien
# soy
# como
# soy
# y
# que
# tengo
# en
# comun
# con
# los
# demas
# como
# cuido
# cuerpo
# que
# hago
# en
# la
# semana
# como
# son
# el
# lugar
# donde
# vivo
# y
# otros
# lugares
# donde
# estan
# mis
# lugares
# favoritos
# como
# celebramos
# el
# inicio
# de
# la
# independencia
# de
# mexico
# que
# aprendi
# autoevaluacion
# evaluacion
# bloque
# soy
# parte
# de
# la
# naturaleza
# la
# naturaleza
# del
# lugar
# donde
# vivo
# cambios
# en
# la
# naturaleza
# del
# lugar
# donde
# vivo
# semejanzas
# y
# diferencias
# entre
# plantas
# y
# animales
# bene
# cios
# y
# riesgos
# de
# plantas
# y
# animales
# como
# celebramos
# el
# inicio
# de
# la
# revolucion
# mexicana
# que
# aprendi
# autoevaluacion
# evaluacion
# bloque
# bloque
# historia
# personal
# y
# familiar
# cuando
# cumplimos
# anos
# mis
# recuerdos
# mas
# importantes
# familia
# ha
# cambiado
# los
# juegos
# y
# juguetes
# de
# ayer
# y
# hoy
# nuestras
# costumbres
# y
# tradiciones
# como
# celebramos
# la
# promulgacion
# de
# la
# constitucion
# politica
# de
# los
# estados
# unidos
# mexicanos
# que
# aprendi
# autoevaluacion
# evaluacion
# bloque
# las
# actividades
# del
# lugar
# donde
# vivo
# el
# lugar
# donde
# vivo
# y
# sus
# casas
# actividades
# de
# las
# personas
# los
# horarios
# de
# trabajo
# y
# esparcimiento
# en
# el
# lugar
# donde
# vivo
# transportes
# del
# lugar
# donde
# vivo
# las
# fuentes
# y
# aplicaciones
# de
# la
# luz
# y
# el
# calor
# en
# el
# lugar
# donde
# vivo
# los
# objetos
# que
# usamos
# de
# que
# materiales
# estan
# hechos
# como
# celebramos
# el
# natalicio
# de
# benito
# juarez
# que
# aprendi
# autoevaluacion
# evaluacion
# bloque
# los
# riesgos
# y
# el
# cuidado
# del
# lugar
# donde
# vivo
# seguridad
# en
# el
# hogar
# los
# riesgos
# y
# las
# zonas
# del
# lugar
# donde
# vivo
# participo
# en
# el
# cuidado
# del
# lugar
# donde
# vivo
# proyecto
# asi
# es
# el
# lugar
# donde
# vivo
# como
# celebramos
# quienes
# lucharon
# en
# la
# batalla
# del
# cinco
# de
# mayo
# que
# aprendi
# autoevaluacion
# evaluacion
# bibliografia
# creditos
# iconograficos
# seccion
# recortable
# conoce
# tu
# libro
# el
# libro
# esta
# organizado
# en
# cinco
# bloques
# con
# actividades
# que
# te
# ayudaran
# a
# explorar
# observar
# y
# descubrir
# la
# naturaleza
# las
# caracteristicas
# de
# tu
# cuerpo
# y
# la
# historia
# del
# lugar
# donde
# vives
# puedes
# realizar
# las
# actividades
# de
# manera
# individual
# en
# equipo
# o
# en
# grupo
# en
# algunas
# es
# importante
# que
# participen
# tambien
# los
# integrantes
# de
# tu
# familia
# los
# trabajos
# finales
# de
# cada
# bloque
# presentan
# el
# siguiente
# orden
# album
# cartel
# album
# personal
# y
# familiar
# y
# periodico
# mural
# en
# el
# bloque
# realizaras
# un
# proyecto
# donde
# utilizaras
# lo
# que
# aprendiste
# durante
# el
# curso
# al
# inicio
# del
# bloque
# encontraras
# informacion
# de
# lo
# que
# realizaras
# durante
# el
# bloque
# asi
# como
# indicaciones
# para
# el
# trabajo
# final
# con
# los
# trabajos
# que
# realices
# en
# el
# bloque
# elaboraras
# un
# album
# en
# el
# que
# ubicaras
# y
# ordenaras
# acontecimientos
# de
# tu
# historia
# personal
# y
# familiar
# conforme
# sucedieron
# al
# final
# lo
# presentaras
# al
# grupo
# hojas
# de
# cartulina
# pegamento
# blanco
# lapices
# de
# colores
# cinta
# adhesiva
# aguja
# de
# caneva
# de
# plastico
# madeja
# de
# estambre
# materiales
# se
# menciona
# lo
# que
# necesitaras
# para
# realizar
# tu
# trabajo
# al
# final
# del
# bloque
# en
# cada
# leccion
# contenido
# el
# titulo
# de
# cada
# leccion
# describe
# lo
# que
# vas
# a
# aprender
# en
# ella
# preguntas
# al
# inicio
# de
# la
# leccion
# se
# incluyen
# interrogantes
# que
# te
# ayudaran
# a
# explorar
# tu
# conocimiento
# sobre
# los
# contenidos
# actividades
# que
# se
# realizaran
# te
# serviran
# para
# ampliar
# tus
# conocimientos
# habilidades
# actitudes
# y
# valores
# para
# apreciar
# y
# cuidar
# el
# lugar
# donde
# vives
# y
# reconocer
# la
# importancia
# de
# algunos
# acontecimientos
# historicos
# al
# final
# del
# bloque
# autoevaluacion
# tendras
# la
# oportunidad
# de
# reflexionar
# acerca
# de
# tu
# aprendizaje
# que
# aprendi
# se
# proporcionan
# indicaciones
# para
# terminar
# el
# producto
# de
# cada
# bloque
# reconoceras
# los
# conocimientos
# habilidades
# actitudes
# y
# valores
# que
# desarrollaste
# ademas
# analizaras
# y
# evaluaras
# los
# productos
# realizados
# por
# tus
# companeros
# para
# aprender
# de
# ellos
# evaluacion
# son
# ejercicios
# que
# al
# final
# de
# cada
# bloque
# integran
# lo
# que
# aprendiste
# tu
# libro
# presenta
# las
# siguientes
# secciones
# a
# jugar
# actividades
# en
# las
# que
# utilizaras
# tus
# conocimientos
# de
# manera
# divertida
# calendario
# senalaras
# la
# fecha
# conmemorativa
# en
# el
# dia
# que
# corresponda
# en
# el
# calendario
# asi
# sabras
# cuando
# se
# celebra
# ese
# evento
# historico
# seccion
# recortable
# cuando
# encuentres
# el
# siguiente
# icono
# utilizaras
# el
# material
# recortable
# ubicado
# en
# las
# ultimas
# paginas
# del
# libro
# consulta
# en
# fuentes
# de
# informacion
# donde
# puedes
# investigar
# mas
# acerca
# del
# contenido
# es
# conveniente
# que
# un
# adulto
# te
# apoye
# al
# realizar
# tus
# investigaciones
# como
# celebramos
# dibujalo
# incluye
# las
# viviendas
# los
# caminos
# los
# comercios
# las
# plantas
# y
# los
# animales
# toma
# en
# cuenta
# su
# cantidad
# colores
# formas
# y
# tamanos
# escribe
# el
# nombre
# del
# lugar
# donde
# vives
# pegalo
# en
# tu
# album
# observa
# las
# postales
# de
# los
# diferentes
# lugares
# que
# el
# maestro
# de
# juan
# y
# carolina
# les
# enseno
# comparalas
# con
# el
# lugar
# donde
# vives
# alamos
# sonora
# bernal
# queretaro
# san
# cristobal
# de
# las
# casas
# chiapas
# puerto
# vallarta
# jalisco
# comenten
# en
# grupo
# en
# que
# se
# parecen
# en
# que
# son
# diferentes
# los
# lugares
# tienen
# caracteristicas
# particulares
# como
# las
# viviendas
# los
# caminos
# los
# comercios
# los
# animales
# y
# las
# plantas
# que
# los
# hacen
# diferentes
# o
# parecidos
# al
# lugar
# donde
# vives
# bloque
# donde
# estan
# mis
# lugares
# favoritos
# como
# localizas
# tus
# lugares
# favoritos
# orientate
# para
# encontrarlos
# carolina
# quiere
# mostrar
# a
# sus
# companeros
# su
# lugar
# favorito
# primero
# lo
# dibujo
# y
# despues
# hizo
# un
# croquis
# para
# que
# sus
# companeros
# supieran
# lo
# que
# hay
# en
# ese
# lugar
# dibujo
# del
# lugar
# favorito
# de
# carolina
# comenta
# con
# un
# companero
# que
# semejanzas
# encuentras
# entre
# el
# dibujo
# y
# el
# croquis
# en
# que
# son
# diferentes
# croquis
# del
# lugar
# mercado
# biblioteca
# tienda
# palacio
# municipal
# centro
# de
# salud
# favorito
# de
# carolina
# en
# el
# croquis
# de
# carolina
# localiza
# lo
# siguiente
# y
# escribe
# las
# respuestas
# en
# tu
# cuaderno
# que
# esta
# a
# la
# izquierda
# del
# quiosco
# que
# lugar
# esta
# lejos
# de
# la
# biblioteca
# que
# lugares
# estan
# a
# la
# derecha
# de
# la
# fuente
# si
# quieres
# ir
# del
# centro
# de
# salud
# a
# la
# tienda
# por
# donde
# tendrias
# que
# pasar
# traza
# el
# recorrido
# en
# el
# croquis
# juega
# con
# tus
# companeros
# a
# localizar
# mas
# lugares
# y
# a
# hacer
# diferentes
# recorridos
# en
# el
# croquis
# en
# equipo
# elaboren
# una
# maqueta
# de
# su
# lugar
# favorito
# en
# la
# que
# muestren
# las
# casas
# los
# arboles
# los
# semaforos
# y
# los
# caminos
# que
# hay
# en
# el
# coloquen
# su
# maqueta
# en
# el
# suelo
# y
# observenla
# desde
# arriba
# cada
# uno
# dibuje
# el
# croquis
# de
# lo
# que
# observa
# comparenlos
# y
# comenten
# en
# que
# se
# parecen
# en
# que
# son
# diferentes
# peguenlos
# en
# los
# albumes
# jugar
# tesoro
# escondido
# comenten
# en
# equipo
# para
# que
# les
# sirvio
# el
# croquis
# bloque
# en
# equipos
# seleccionen
# un
# objeto
# para
# que
# sea
# el
# tesoro
# escondan
# en
# la
# escuela
# su
# tesoro
# elaboren
# un
# croquis
# para
# encontrarlo
# intercambien
# su
# croquis
# con
# otro
# equipo
# busquen
# el
# tesoro
# los
# croquis
# te
# ayudan
# a
# localizar
# lugares
# como
# celebramos
# el
# inicio
# de
# la
# independencia
# de
# mexico
# por
# que
# es
# importante
# conmemorar
# y
# celebrar
# el
# inicio
# de
# la
# lucha
# por
# la
# independencia
# de
# mexico
# como
# lo
# celebran
# en
# tu
# comunidad
# escucha
# con
# atencion
# y
# conoceras
# la
# historia
# anota
# la
# fecha
# en
# el
# calendario
# septiembre
# do
# lu
# ma
# ju
# sa
# con
# ayuda
# de
# un
# croquis
# carolina
# le
# mostro
# a
# antonio
# como
# llegar
# al
# palacio
# municipal
# de
# papantla
# veracruz
# para
# que
# pudiera
# ir
# a
# la
# ceremonia
# del
# grito
# en
# la
# que
# se
# conmemora
# el
# inicio
# de
# la
# lucha
# por
# la
# independencia
# de
# mexico
# celebrada
# en
# todo
# el
# pais
# palacio
# municipal
# de
# papantla
# ciudad
# de
# papantla
# veracruz
# el
# maestro
# de
# carolina
# les
# conto
# la
# siguiente
# historia
# bloque
# las
# reuniones
# fueron
# descubiertas
# por
# lo
# que
# en
# la
# madrugada
# del
# de
# septiembre
# de
# hidalgo
# hizo
# sonar
# la
# campana
# de
# la
# parroquia
# de
# dolores
# guanajuato
# para
# llamar
# a
# la
# gente
# a
# luchar
# de
# esta
# manera
# comenzo
# la
# guerra
# por
# la
# independencia
# de
# mexico
# el
# cura
# miguel
# hidalgo
# y
# costilla
# defendio
# a
# los
# pueblos
# indigenas
# y
# lucho
# por
# la
# desaparicion
# de
# la
# esclavitud
# y
# asi
# gracias
# al
# movimiento
# que
# inicio
# mexico
# esta
# entre
# los
# paises
# libres
# del
# mundo
# bloque
# enumera
# las
# imagenes
# segun
# sucedieron
# los
# hechos
# como
# se
# conmemora
# y
# celebra
# la
# independencia
# de
# mexico
# en
# el
# lugar
# donde
# vives
# dibujalo
# en
# una
# estampa
# y
# pegala
# en
# tu
# album
# la
# lucha
# iniciada
# por
# miguel
# hidalgo
# termino
# en
# la
# independencia
# de
# mexico
# por
# eso
# cada
# ano
# se
# conmemora
# y
# celebra
# el
# comienzo
# de
# este
# movimiento
# por
# la
# libertad
# de
# nuestro
# pais
# que
# aprendi
# organiza
# los
# trabajos
# de
# tu
# album
# puedes
# hacerlo
# como
# se
# muestra
# en
# la
# imagen
# los
# cuidados
# de
# cuerpo
# yo
# y
# lo
# que
# me
# gusta
# como
# celebramos
# el
# inicio
# de
# la
# independencia
# de
# mexico
# valorar
# el
# trabajo
# de
# tus
# companeros
# te
# permite
# aprender
# de
# los
# demas
# en
# parejas
# intercambien
# su
# album
# comenten
# el
# album
# en
# el
# grupo
# a
# partir
# de
# las
# preguntas
# siguientes
# que
# es
# lo
# que
# mas
# le
# gusta
# hacer
# a
# tu
# companero
# en
# su
# vida
# diaria
# en
# que
# se
# parece
# tu
# companero
# a
# los
# demas
# que
# sentidos
# represento
# tu
# companero
# en
# sus
# dibujos
# como
# se
# celebra
# el
# inicio
# de
# la
# independencia
# de
# mexico
# en
# el
# lugar
# donde
# vive
# a
# partir
# del
# croquis
# que
# trazo
# cual
# es
# su
# lugar
# favorito
# que
# fue
# lo
# que
# mas
# te
# gusto
# del
# album
# de
# tu
# companero
# por
# que
# que
# aprendiste
# de
# tu
# companero
# autoevaluacion
# es
# momento
# de
# reflexionar
# y
# reconocer
# tus
# logros
# une
# con
# una
# linea
# el
# dibujo
# que
# responda
# la
# pregunta
# como
# cuido
# cuerpo
# como
# celebro
# el
# inicio
# de
# la
# lucha
# por
# la
# independencia
# de
# mexico
# donde
# estan
# mis
# lugares
# favoritos
# marca
# con
# una
# palomita
# lo
# que
# lograste
# durante
# el
# bloque
# y
# explica
# por
# que
# si
# no
# expreso
# las
# caracteristicas
# que
# me
# identifican
# si
# no
# ordeno
# correctamente
# las
# actividades
# que
# realizo
# durante
# el
# dia
# la
# tarde
# y
# la
# noche
# siempre
# lo
# hago
# lo
# hago
# a
# veces
# dificilmente
# lo
# hago
# participo
# en
# las
# celebraciones
# del
# inicio
# de
# la
# lucha
# por
# la
# independencia
# de
# mexico
# evaluacion
# recorta
# el
# tablero
# de
# la
# pagina
# despues
# recorta
# las
# tarjetas
# de
# la
# pagina
# juega
# y
# pon
# en
# practica
# lo
# que
# aprendiste
# en
# el
# bloque
# lee
# las
# instrucciones
# que
# se
# encuentran
# al
# reverso
# de
# la
# pagina
# y
# juega
# con
# tus
# companeros
# y
# familiares
# las
# tarjetas
# de
# estas
# paginas
# pertenecen
# al
# primer
# nivel
# al
# terminar
# cada
# bloque
# obtendras
# mas
# tarjetas
# para
# avanzar
# a
# otros
# niveles
# autoevaluacionii
# bloq
# soy
# parte
# de
# la
# naturaleza
# con
# las
# actividades
# identificaras
# como
# formas
# parte
# de
# la
# naturaleza
# al
# final
# elaboraras
# en
# equipo
# un
# cartel
# para
# presentar
# informacion
# breve
# acerca
# de
# uno
# de
# los
# contenidos
# que
# aprenderas
# en
# el
# bloque
# y
# despues
# lo
# mostraras
# al
# resto
# del
# grupo
# cartulina
# pegamento
# blanco
# tijeras
# de
# punta
# roma
# colores
# plumones
# libros
# revistas
# periodicos
# bloqueii
# la
# naturaleza
# del
# lugar
# donde
# vivo
# cuales
# son
# las
# caracteristicas
# de
# los
# componentes
# naturales
# del
# lugar
# donde
# vives
# al
# observarlas
# las
# conoceras
# el
# maestro
# de
# tonantzin
# organizo
# un
# paseo
# y
# todos
# los
# companeros
# del
# salon
# se
# pusieron
# muy
# contentos
# observa
# y
# describe
# lo
# que
# tonantzin
# y
# sus
# companeros
# vieron
# en
# su
# paseo
# comenta
# como
# son
# las
# plantas
# que
# animales
# observas
# donde
# viven
# como
# es
# el
# terreno
# que
# mas
# observas
# en
# el
# lugar
# donde
# vives
# hay
# montanas
# rios
# o
# lagos
# hay
# animales
# y
# plantas
# como
# son
# recorta
# las
# imagenes
# de
# la
# pagina
# y
# pegalas
# para
# completar
# el
# siguiente
# dibujo
# las
# montanas
# los
# rios
# las
# plantas
# los
# animales
# el
# suelo
# y
# el
# sol
# son
# ejemplos
# y
# cada
# uno
# caminara
# en
# diferentes
# direcciones
# alguien
# dice
# nidos
# de
# nidos
# de
# o
# nidos
# de
# y
# ese
# numero
# de
# ninos
# se
# colocara
# en
# el
# centro
# del
# nido
# recorta
# el
# tablero
# de
# la
# pagina
# y
# juega
# serpientes
# y
# escaleras
# los
# animales
# y
# las
# plantas
# cambian
# al
# nacer
# al
# crecer
# al
# reproducirse
# y
# al
# morir
# semejanzas
# y
# diferencias
# entre
# plantas
# y
# animales
# cuales
# son
# las
# caracteristicas
# de
# las
# plantas
# y
# de
# los
# animales
# clasificalos
# y
# lo
# sabras
# tonantzin
# y
# su
# grupo
# realizaron
# una
# excursion
# a
# la
# playa
# se
# dieron
# cuenta
# de
# que
# los
# animales
# y
# las
# plantas
# que
# hay
# ahi
# son
# diferentes
# a
# los
# del
# lugar
# donde
# viven
# que
# observas
# en
# la
# imagen
# comentalo
# con
# el
# grupo
# bloqueii
# hay
# animales
# grandes
# y
# pequenos
# algunos
# viven
# en
# el
# agua
# otros
# en
# la
# tierra
# estan
# los
# que
# vuelan
# o
# reptan
# algunos
# tienen
# pelo
# otros
# plumas
# existen
# los
# que
# tienen
# escamas
# y
# aquellos
# que
# poseen
# muchos
# colores
# estan
# los
# que
# pueden
# convivir
# directamente
# con
# el
# ser
# humano
# y
# los
# que
# no
# nombre
# anolis
# vive
# en
# medio
# terrestre
# como
# es
# pequeno
# cambia
# de
# color
# con
# la
# luz
# y
# tiene
# cola
# larga
# se
# nutre
# de
# insectos
# un
# dato
# interesante
# entre
# las
# aves
# la
# mas
# grande
# es
# el
# avestruz
# mientras
# que
# el
# colibri
# es
# la
# mas
# pequena
# nombre
# ballena
# jorobada
# vive
# en
# medio
# acuatico
# como
# es
# grande
# tiene
# aletas
# y
# puede
# saltar
# se
# nutre
# de
# krill
# y
# peces
# nombre
# berrendo
# vive
# en
# medio
# terrestre
# como
# es
# tiene
# cuernos
# pelo
# cafe
# y
# cuatro
# patas
# se
# nutre
# de
# hierbas
# arbustos
# y
# cactus
# bloqueii
# nombre
# armadillo
# vive
# en
# medio
# terrestre
# como
# es
# tiene
# caparazon
# patas
# cortas
# y
# cola
# larga
# se
# nutre
# de
# insectos
# y
# sus
# larvas
# y
# de
# plantas
# nombre
# pez
# ballesta
# vive
# en
# medio
# acuatico
# como
# es
# tiene
# muchos
# colores
# aletas
# y
# ojos
# pequenos
# se
# nutre
# de
# conchas
# y
# algas
# hay
# plantas
# grandes
# y
# pequenas
# de
# diferentes
# colores
# y
# formas
# con
# espinas
# y
# sin
# ellas
# otras
# crecen
# en
# el
# agua
# unas
# dan
# frutos
# y
# ores
# y
# algunas
# se
# utilizan
# como
# adorno
# nombre
# aguacate
# vive
# en
# medio
# terrestre
# como
# es
# alto
# tiene
# flores
# y
# frutos
# se
# nutre
# de
# agua
# minerales
# del
# suelo
# y
# luz
# del
# sol
# nombre
# orquidea
# vive
# en
# medio
# terrestre
# como
# es
# tiene
# flores
# de
# diversos
# colores
# y
# tamanos
# tus
# companeros
# analiza
# el
# siguiente
# ejemplo
# observa
# como
# se
# pueden
# clasificar
# las
# hojas
# por
# su
# tamano
# de
# que
# otra
# manera
# podrian
# clasificarse
# bloqueii
# observa
# como
# se
# pueden
# clasificar
# los
# animales
# por
# el
# lugar
# donde
# viven
# animales
# que
# viven
# animales
# que
# viven
# en
# un
# medio
# acuatico
# en
# un
# medio
# terrestre
# recorta
# dibujos
# de
# animales
# y
# clasificalos
# por
# tamano
# cantidad
# de
# patas
# si
# tienen
# plumas
# o
# pelo
# o
# por
# el
# lugar
# donde
# viven
# pegalos
# en
# una
# hoja
# y
# comenta
# que
# caracteristicas
# tomaste
# en
# cuenta
# para
# clasificarlos
# un
# dato
# interesante
# el
# ojo
# del
# avestruz
# es
# mas
# grande
# que
# su
# cerebro
# el
# tamano
# el
# color
# y
# la
# forma
# son
# algunas
# caracteristicas
# que
# permiten
# clasi
# car
# plantas
# y
# animales
# beneficios
# y
# riesgos
# de
# plantas
# y
# animales
# que
# beneficios
# obtienen
# las
# personas
# de
# las
# plantas
# y
# los
# animales
# del
# lugar
# donde
# vives
# que
# riesgos
# representan
# tonantzin
# y
# sus
# amigos
# disfrutan
# de
# la
# compania
# de
# los
# animales
# y
# plantas
# que
# hay
# cerca
# de
# su
# casa
# explica
# lo
# que
# observas
# en
# la
# ilustracion
# de
# los
# animales
# y
# las
# plantas
# obtenemos
# alimentos
# y
# materiales
# para
# vestir
# y
# calzar
# ademas
# las
# plantas
# contribuyen
# a
# limpiar
# el
# aire
# dibuja
# plantas
# y
# animales
# del
# lugar
# donde
# vives
# y
# explica
# por
# que
# son
# importantes
# para
# tu
# vida
# elabora
# varias
# frases
# sobre
# los
# cuidados
# que
# necesitan
# las
# plantas
# y
# los
# animales
# bloqueii
# jugar
# encuentra
# a
# tu
# pareja
# imita
# a
# un
# animal
# busca
# a
# un
# companero
# que
# imite
# al
# mismo
# animal
# que
# elegiste
# gana
# quien
# encuentre
# a
# su
# pareja
# hay
# plantas
# y
# animales
# que
# habitan
# en
# el
# lugar
# donde
# vives
# y
# que
# pueden
# resultar
# peligrosos
# si
# los
# tocas
# o
# molestas
# escribe
# en
# tu
# cuaderno
# su
# nombre
# por
# que
# pueden
# ser
# peligrosos
# por
# que
# es
# necesario
# tener
# cuidado
# con
# ciertos
# animales
# y
# plantas
# investigalo
# serpiente
# alacran
# cactus
# es
# importante
# que
# respetes
# las
# plantas
# y
# los
# animales
# cuando
# sientas
# peligro
# alejate
# si
# algun
# animal
# te
# pica
# o
# muerde
# o
# si
# una
# planta
# te
# irrita
# la
# piel
# pide
# que
# te
# lleven
# de
# inmediato
# al
# centro
# de
# salud
# mas
# cercano
# ecuerda
# que
# es
# importante
# cuidar
# las
# plantas
# y
# los
# animales
# ya
# que
# los
# seres
# humanos
# dependemos
# de
# ellos
# un
# dato
# interesante
# las
# tarantulas
# se
# alimentan
# de
# insectos
# por
# lo
# que
# ayudan
# a
# que
# estos
# no
# se
# conviertan
# en
# una
# plaga
# revolucion
# mexicana
# los
# trenes
# fueron
# muy
# importantes
# en
# la
# revolucion
# mexicana
# sirvieron
# para
# transportar
# a
# la
# tropas
# y
# realizar
# campamentos
# incluso
# como
# hospitales
# onsulta
# en
# para
# profundizar
# en
# el
# contenido
# entra
# a
# httpbasicaprimariatic
# sepgobmx
# haz
# en
# busca
# y
# en
# el
# buscador
# anota
# revolucion
# mexicana
# villa
# o
# zapata
# que
# aprendi
# formen
# equipos
# cada
# uno
# elabore
# su
# cartel
# retomando
# una
# de
# las
# frases
# que
# escribieron
# a
# lo
# largo
# del
# bloque
# su
# cartel
# debe
# tener
# los
# siguientes
# elementos
# titulo
# o
# encabezado
# imagen
# un
# dibujo
# un
# recorte
# o
# una
# fotografia
# una
# frase
# que
# desees
# que
# recuerden
# quienes
# vean
# el
# cartel
# los
# nombres
# de
# quienes
# hicieron
# el
# cartel
# peguen
# los
# carteles
# en
# el
# patio
# de
# la
# escuela
# seleccionen
# un
# cartel
# de
# otro
# equipo
# y
# comenten
# con
# sus
# companeros
# lo
# que
# les
# gusto
# analicen
# por
# ejemplo
# las
# frases
# expresan
# con
# claridad
# la
# idea
# que
# se
# quiere
# transmitir
# pueden
# identi
# car
# los
# cambios
# que
# se
# dan
# en
# la
# naturaleza
# que
# mensaje
# fue
# el
# mas
# importante
# por
# que
# autoevaluacion
# es
# momento
# de
# reflexionar
# y
# reconocer
# tus
# logros
# observa
# las
# imagenes
# en
# tu
# cuaderno
# realiza
# lo
# siguiente
# describe
# los
# componentes
# naturales
# que
# observas
# con
# ayuda
# de
# las
# imagenes
# explica
# las
# etapas
# de
# crecimiento
# de
# un
# aguila
# marca
# con
# una
# palomita
# lo
# que
# lograste
# durante
# el
# bloque
# clasifico
# plantas
# y
# animales
# a
# partir
# de
# sus
# caracteristicas
# si
# no
# frio
# lluvia
# calor
# viento
# distingo
# los
# cambios
# de
# la
# naturaleza
# durante
# el
# ano
# si
# no
# reconozco
# el
# beneficio
# de
# plantas
# y
# animales
# y
# participo
# en
# su
# cuidado
# valoro
# la
# importancia
# de
# la
# revolucion
# mexicana
# en
# vida
# evaluacion
# juega
# y
# pon
# en
# practica
# lo
# que
# aprendiste
# en
# el
# bloque
# recorta
# las
# tarjetas
# de
# la
# pagina
# para
# jugar
# el
# segundo
# nivel
# siempre
# lo
# hago
# lo
# hago
# a
# veces
# dificilmente
# lo
# hago
# siempre
# lo
# hago
# lo
# hago
# a
# veces
# dificilmente
# lo
# hago
# bloq
# historia
# personal
# y
# familiar
# con
# los
# trabajos
# que
# realices
# en
# el
# bloque
# elaboraras
# un
# album
# en
# el
# que
# ubicaras
# y
# ordenaras
# acontecimientos
# de
# tu
# historia
# personal
# y
# familiar
# conforme
# sucedieron
# al
# final
# lo
# presentaras
# al
# grupo
# hojas
# de
# cartulina
# pegamento
# blanco
# lapices
# de
# colores
# cinta
# adhesiva
# aguja
# de
# caneva
# de
# plastico
# madeja
# de
# estambre
# bloqueiii
# cuando
# cumplimos
# anos
# que
# el
# numero
# de
# integrantes
# son
# algunos
# ejemplos
# de
# los
# cambios
# que
# suceden
# en
# tu
# familia
# cuando
# crezcas
# sera
# diferente
# de
# como
# es
# ahora
# bloqueiii
# los
# juegos
# y
# juguetes
# de
# ayer
# y
# hoy
# en
# que
# se
# parecen
# los
# juegos
# de
# tus
# padres
# y
# los
# de
# tus
# abuelos
# a
# los
# tuyos
# en
# que
# han
# cambiado
# los
# juguetes
# pregunta
# juega
# y
# compara
# los
# abuelos
# de
# diana
# le
# mostraron
# juguetes
# ropa
# y
# otros
# objetos
# que
# usaban
# cuando
# eran
# ninos
# investiga
# el
# nombre
# de
# los
# juguetes
# de
# las
# paginas
# y
# y
# como
# se
# juegan
# comenta
# con
# tus
# companeros
# en
# que
# se
# parecen
# a
# los
# juguetes
# de
# hoy
# en
# que
# son
# diferentes
# con
# cuales
# has
# jugado
# investiga
# a
# que
# jugaban
# tus
# abuelos
# cuando
# eran
# ninos
# elabora
# un
# dibujo
# del
# juego
# que
# mas
# les
# gustaba
# e
# integralo
# a
# tu
# album
# personal
# y
# familiar
# de
# los
# juegos
# que
# practicaban
# cuales
# sigues
# jugando
# comentalo
# con
# tus
# companeros
# jugar
# los
# juegos
# de
# ayer
# hoy
# y
# siempre
# vibora
# de
# la
# mar
# gallinita
# ciega
# bloqueiii
# elige
# uno
# de
# los
# siguientes
# juegos
# y
# practicalo
# con
# tus
# companeros
# escondidas
# hay
# juegos
# y
# juguetes
# que
# a
# pesar
# del
# tiempo
# se
# siguen
# jugando
# de
# la
# misma
# manera
# y
# tambien
# hay
# otros
# que
# han
# cambiado
# nuestras
# costumbres
# y
# tradiciones
# que
# costumbres
# un
# dia
# muy
# temprano
# lucia
# escucho
# y
# tradiciones
# se
# a
# su
# mama
# decir
# que
# preparaba
# celebran
# donde
# todo
# para
# la
# esta
# le
# pregunto
# vives
# cuales
# en
# a
# su
# abuela
# que
# celebramos
# y
# ella
# otros
# lugares
# le
# contesto
# que
# se
# trataba
# de
# la
# esta
# al
# describirlas
# del
# pueblo
# que
# se
# celebra
# ano
# con
# ano
# las
# tradiciones
# como
# las
# estas
# encontraras
# anuales
# en
# los
# pueblos
# y
# la
# manera
# la
# respuesta
# en
# que
# se
# acostumbra
# festejarlas
# se
# transmiten
# de
# generacion
# en
# generacion
# en
# mexico
# muchos
# pueblos
# han
# conservado
# sus
# tradiciones
# los
# pueblos
# indigenas
# ademas
# mantienen
# vivas
# sus
# lenguas
# maternas
# con
# las
# que
# se
# comunican
# diariamente
# describan
# en
# grupo
# como
# se
# preparan
# para
# la
# fiesta
# en
# el
# pueblo
# de
# lucia
# comenten
# las
# siguientes
# preguntas
# que
# costumbres
# y
# tradiciones
# hay
# en
# el
# lugar
# donde
# viven
# con
# que
# frecuencia
# las
# realizan
# en
# que
# fechas
# y
# por
# que
# se
# celebran
# bloqueiii
# dibuja
# y
# describe
# en
# una
# hoja
# como
# se
# celebran
# las
# fiestas
# populares
# en
# el
# lugar
# donde
# vives
# comparte
# la
# informacion
# con
# tus
# companeros
# observa
# las
# siguientes
# imagenes
# investiga
# que
# festejo
# se
# ilustra
# y
# escribe
# en
# tu
# cuaderno
# el
# nombre
# de
# cada
# uno
# nsulta
# en
# para
# profundizar
# en
# el
# contenido
# entra
# a
# httpbasicaprimariatic
# sepgobmx
# haz
# en
# busca
# y
# en
# el
# buscador
# anota
# costumbres
# o
# tradiciones
# tambien
# puedes
# preguntar
# a
# tu
# profesor
# por
# el
# siguiente
# libro
# de
# la
# biblioteca
# escolar
# maria
# de
# la
# luz
# mendoza
# soy
# purepecha
# mexico
# sep
# el
# dia
# de
# muertos
# y
# las
# estas
# patrias
# son
# tradiciones
# que
# se
# celebran
# en
# el
# pais
# pero
# en
# cada
# lugar
# se
# acostumbra
# festejarlas
# de
# diferente
# manera
# como
# celebramos
# la
# promulgacion
# de
# la
# constitucion
# politica
# de
# los
# estados
# unidos
# mexicanos
# febrero
# do
# lu
# ma
# ju
# sa
# por
# que
# es
# importante
# para
# los
# mexicanos
# conmemorar
# el
# de
# febrero
# como
# lo
# celebran
# en
# tu
# comunidad
# escucha
# y
# lo
# descubriras
# anota
# la
# fecha
# en
# el
# calendario
# al
# investigar
# las
# fechas
# importantes
# para
# todos
# los
# mexicanos
# joaquin
# y
# diana
# descubrieron
# que
# el
# de
# febrero
# se
# conmemora
# en
# todo
# el
# pais
# el
# dia
# de
# la
# constitucion
# politica
# de
# los
# estados
# unidos
# mexicanos
# que
# fue
# el
# resultado
# de
# las
# ideas
# de
# los
# diferentes
# grupos
# que
# lucharon
# en
# la
# revolucion
# mexicana
# esta
# constitucion
# se
# dio
# a
# conocer
# el
# de
# febrero
# de
# la
# constitucion
# es
# la
# principal
# ley
# de
# nuestro
# pais
# es
# mportante
# porque
# enuncia
# los
# derechos
# y
# deberes
# de
# las
# personas
# por
# ejemplo
# el
# derecho
# a
# la
# educacion
# al
# trabajo
# y
# a
# la
# salud
# actualmente
# la
# constitucion
# reconoce
# los
# derechos
# de
# los
# ninos
# establecidos
# en
# la
# convencion
# de
# los
# derechos
# del
# nino
# un
# dato
# interesante
# la
# constitucion
# reconoce
# que
# mexico
# es
# un
# pais
# con
# una
# gran
# diversidad
# cultural
# y
# linguistica
# eso
# significa
# que
# en
# nuestra
# nacion
# habitan
# numerosos
# pueblos
# con
# lenguas
# y
# culturas
# distintas
# bloqueiii
# lee
# y
# comenta
# la
# rima
# gracias
# a
# mis
# derechos
# bien
# estoy
# cuando
# cumplo
# con
# mis
# deberes
# responsable
# soy
# con
# mis
# derechos
# y
# deberes
# feliz
# estoy
# observa
# y
# completa
# los
# derechos
# y
# deberes
# de
# los
# ninos
# que
# se
# muestran
# en
# las
# imagenes
# de
# esta
# y
# la
# siguiente
# pagina
# derecho
# a
# no
# ser
# maltratado
# deber
# derecho
# deber
# lavarse
# los
# dientes
# tres
# veces
# al
# dia
# derecho
# a
# ir
# a
# la
# escuela
# deber
# derecho
# deber
# conservar
# en
# buen
# estado
# los
# juegos
# en
# los
# mexicanos
# lograron
# derrotarlo
# y
# defendieron
# el
# territorio
# mexicano
# de
# esa
# injusta
# invasion
# comenten
# en
# grupo
# la
# informacion
# que
# encontraron
# maria
# y
# rafael
# sobre
# lo
# sucedido
# en
# la
# batalla
# del
# cinco
# de
# mayo
# por
# que
# es
# importante
# para
# los
# mexicanos
# lo
# sucedido
# en
# esta
# fecha
# observa
# la
# imagen
# de
# la
# celebracion
# del
# cinco
# de
# mayo
# en
# puebla
# como
# lo
# celebran
# en
# tu
# escuela
# comentalo
# con
# tus
# companeros
# el
# ejercito
# republicano
# y
# los
# indigenas
# nahuas
# zacapoaxtlas
# vencieron
# al
# ejercito
# frances
# un
# dato
# interesante
# la
# batalla
# de
# puebla
# no
# solo
# se
# conmemora
# en
# mexico
# en
# estados
# unidos
# de
# america
# la
# celebran
# porque
# consideran
# que
# de
# no
# haber
# triunfado
# los
# mexicanos
# los
# franceses
# habrian
# intentado
# atacar
# su
# pais
# onsulta
# en
# para
# profundizar
# en
# el
# contenido
# entra
# a
# httpbasicaprimariaticsepgobmx
# haz
# en
# busca
# y
# en
# colecciones
# entra
# a
# fonoteca
# nacional
# dirigete
# a
# estampas
# sonoras
# del
# bicentenario
# donde
# podras
# escuchar
# el
# audio
# las
# armas
# nacionales
# se
# han
# cubierto
# de
# gloria
# que
# aprendi
# evaluen
# su
# proyecto
# de
# la
# guia
# turistica
# intercambien
# entre
# equipos
# su
# trabajo
# en
# grupo
# revisen
# y
# comenten
# el
# proyecto
# a
# partir
# de
# lo
# siguiente
# cual
# es
# el
# contenido
# del
# proyecto
# que
# eligieron
# analizar
# las
# preguntas
# que
# plantearon
# fueron
# claras
# permitieron
# conocer
# mas
# acerca
# del
# tema
# que
# utilizaron
# para
# realizar
# sus
# investigaciones
# y
# conocer
# mas
# sobre
# el
# contenido
# que
# fue
# lo
# que
# mas
# les
# gusto
# de
# la
# guia
# turistica
# que
# lugares
# tradiciones
# y
# costumbres
# resalto
# cada
# equipo
# por
# que
# son
# importantes
# ubicaron
# zonas
# de
# riesgo
# hicieron
# recomendaciones
# para
# prevenir
# riesgos
# autoevaluacion
# es
# momento
# de
# reflexionar
# y
# reconocer
# tus
# logros
# observa
# la
# imagen
# y
# marca
# los
# riesgos
# del
# lugar
# explica
# por
# que
# se
# celebra
# la
# batalla
# del
# cinco
# de
# mayo
# marca
# con
# una
# palomita
# lo
# que
# lograste
# en
# este
# bloque
# si
# no
# represento
# en
# un
# croquis
# las
# zonas
# de
# seguridad
# cercanas
# siempre
# lo
# hago
# lo
# hago
# a
# veces
# dificilmente
# lo
# hago
# participo
# en
# actividades
# para
# cuidar
# la
# naturaleza
# siempre
# lo
# hago
# lo
# hago
# a
# veces
# dificilmente
# lo
# hago
# promuevo
# el
# lugar
# donde
# vivo
# evaluacion
# juega
# y
# pon
# en
# practica
# lo
# que
# aprendiste
# en
# el
# bloque
# recorta
# las
# tarjetas
# de
# la
# pagina
# pues
# con
# ellas
# ugaras
# el
# quinto
# nivel
# entender
# las
# actividades
# mucho
# regular
# poco
# las
# instrucciones
# de
# las
# actividades
# fueron
# claras
# siempre
# casi
# siempre
# algunas
# veces
# ademas
# de
# los
# libros
# de
# texto
# que
# son
# tuyos
# hay
# otros
# libros
# en
# tu
# aula
# si
# no
# tienes
# en
# tu
# casa
# libros
# que
# no
# sean
# los
# de
# texto
# gratuito
# si
# no
# acostumbras
# leer
# los
# libros
# de
# texto
# gratuitos
# con
# los
# adultos
# de
# tu
# casa
# si
# no
# consultas
# los
# libros
# del
# rincon
# de
# la
# biblioteca
# de
# tu
# escuela
# si
# no
# por
# que
# si
# tienes
# alguna
# sugerencia
# para
# mejorar
# este
# libro
# o
# sobre
# los
# materiales
# educativos
# escribela
# aqui
# gracias
# por
# tu
# participacion
# direccion
# general
# adjunta
# para
# la
# articulacion
# curricular
# de
# la
# educacion
# basica
# reforma
# septimo
# piso
# col
# juarez
# delegacion
# cuauhtemoc
# p
# mexico
# f
# doblar
# aqui
# datos
# generales
# entidad
# escuela
# turno
# matutino
# vespertino
# escuela
# de
# tiempo
# completo
# nombre
# del
# alumno
# domicilio
# del
# alumno
# grado
# doblar
# aqui
# seccion
# recortable
# pagina
# como
# puedes
# prevenir
# un
# accidente
# en
# casa
# a
# colocar
# cada
# cosa
# en
# su
# lugar
# b
# utilizar
# envases
# para
# guardar
# liquidos
# desconocidos
# dejar
# objetos
# regados
# puedo
# participar
# en
# el
# cuidado
# de
# la
# naturaleza
# al
# a
# proteger
# a
# los
# animales
# b
# tirar
# desechos
# en
# la
# calle
# arrancar
# hojas
# a
# las
# plantas
# cuales
# son
# las
# zonas
# de
# seguridad
# a
# lugares
# en
# los
# que
# puedes
# protegerte
# b
# lugares
# en
# los
# que
# puedes
# hacerte
# dano
# lugares
# en
# los
# que
# puede
# ocurrir
# un
# accidente
# como
# se
# celebra
# la
# batalla
# del
# cinco
# de
# mayo
# a
# con
# representaciones
# y
# desfiles
# b
# con
# fiestas
# y
# convivios
# cuidando
# la
# naturaleza
# una
# accion
# que
# afecta
# a
# la
# naturaleza
# es
# a
# desperdiciar
# el
# agua
# b
# separar
# los
# desechos
# apagar
# la
# luz
# cuando
# no
# la
# uso
# en
# que
# batalla
# los
# franceses
# querian
# apoderarse
# del
# territorio
# mexicano
# a
# batalla
# de
# morelos
# b
# batalla
# de
# puebla
# batalla
# de
# san
# luis
# seccion
# recortable
# pagina
# los
# materiales
# con
# los
# que
# puede
# estar
# hecha
# una
# casa
# son
# a
# cristal
# plastico
# y
# corcho
# b
# unicel
# tela
# y
# papel
# adobe
# ladrillo
# y
# cemento
# ordena
# los
# relojes
# de
# acuerdo
# con
# la
# hora
# de
# la
# tarde
# que
# marcan
# a
# b
# las
# principales
# actividades
# que
# realiza
# la
# gente
# de
# comunidad
# son
# respuesta
# libre
# cual
# es
# la
# importancia
# de
# los
# transportes
# a
# llevar
# productos
# de
# un
# lugar
# a
# otro
# b
# contaminar
# el
# aire
# provocar
# transito
# el
# instrumento
# que
# marca
# la
# hora
# se
# llama
# a
# regla
# b
# calendario
# reloj
# son
# fuentes
# de
# luz
# y
# de
# calor
# artificiales
# a
# sol
# fuego
# y
# lampara
# b
# vela
# lampara
# y
# foco
# luna
# estrellas
# y
# sol
# a
# metal
# b
# tela
# vidrio
# hecha
# quede
# mochilatu
# estamaterial
# companeros
# conobjetoscompartirc
# nuestrasson
# noquecosaslastomarbpersonasarespetarademaslas
# los
# de
# cual
# es
# el
# significado
# del
# lema
# benito
# juarez
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# que
# buscas
# para
# ubicar
# una
# fecha
# en
# el
# calendario
# a
# la
# hora
# y
# el
# mes
# del
# acontecimiento
# b
# el
# mes
# y
# el
# dia
# del
# acontecimiento
# el
# lugar
# y
# la
# hora
# del
# acontecimiento
# narra
# un
# acontecimiento
# importante
# en
# tu
# vida
# utiliza
# frases
# como
# antes
# cuando
# era
# pequeno
# o
# cuando
# tenia
# respuesta
# libre
# ordena
# los
# cambios
# que
# ha
# tenido
# con
# el
# tiempo
# la
# familia
# de
# jose
# ahora
# tiene
# un
# hermanito
# despues
# se
# cambiaron
# de
# casa
# antes
# su
# abuelito
# vivia
# con
# ellos
# a
# b
# explica
# en
# que
# han
# cambiado
# los
# juguetes
# de
# antes
# comparados
# con
# los
# que
# utilizas
# ahora
# respuesta
# libre
# en
# que
# puedes
# notar
# que
# los
# juegos
# no
# han
# cambiado
# con
# el
# tiempo
# a
# en
# el
# nombre
# b
# en
# la
# manera
# de
# jugarlos
# en
# los
# materiales
# que
# se
# necesitan
# el
# dia
# de
# muertos
# es
# a
# carnaval
# b
# desfile
# tradicion
# y
# los
# ninos
# tienen
# las
# ninas
# es
# un
# derecho
# que
# lavar
# los
# trastes
# b
# hacer
# la
# tarea
# a
# asistir
# a
# la
# escuela
# importante
# porque
# mexicanos
# es
# estados
# unidos
# politica
# de
# los
# la
# constitucion
# contiene
# derechos
# ydeberesdelosmexicanos
# es
# el
# libro
# mas
# antiguo
# de
# mexicocontiene
# historias
# demexico
# a
# b
# seccion
# recortable
# pagina
# es
# un
# componente
# natural
# a
# suelo
# b
# personas
# gobierno
# cuales
# son
# las
# etapas
# del
# ciclo
# de
# vida
# de
# plantas
# y
# animales
# a
# crecimiento
# muerte
# y
# nacimiento
# b
# reproduccion
# nacimiento
# y
# se
# cambian
# de
# lugar
# nacen
# crecen
# se
# reproducen
# y
# mueren
# las
# caracteristicas
# de
# plantas
# y
# animales
# del
# lugar
# donde
# vives
# son
# respuesta
# libre
# algunas
# caracteristicas
# para
# clasificar
# plantas
# y
# animales
# son
# a
# tamano
# forma
# y
# lugar
# donde
# habitan
# b
# alimento
# y
# cambios
# en
# la
# naturaleza
# frio
# calor
# y
# tamano
# cuales
# son
# los
# cambios
# en
# la
# naturaleza
# durante
# el
# ano
# a
# frio
# calor
# lluvia
# y
# viento
# b
# sol
# luna
# y
# estrellas
# rio
# lago
# mar
# y
# lagunas
# algunos
# riesgos
# de
# plantas
# y
# animales
# pueden
# ser
# a
# mordeduras
# y
# picaduras
# b
# contaminacion
# del
# agua
# y
# aire
# plagas
# y
# enfermedades
# como
# se
# celebra
# eliniciodelarevolucionmexicana
# a
# con
# ceremonias
# y
# desfilesblanzandofuegosartificialescconofrendasycalaveritasliterarias
# seccion
# recortable
# pagina
# pagina
# seccion
# recortable
# instrucciones
# para
# jugar
# necesitaran
# un
# par
# de
# dados
# por
# turnos
# lancen
# el
# dado
# y
# el
# numero
# que
# salga
# seran
# las
# casillas
# que
# avanzaran
# si
# te
# toca
# en
# una
# escalera
# subiras
# si
# te
# toca
# en
# la
# cola
# de
# una
# serpiente
# te
# hara
# descender
# hasta
# donde
# esta
# la
# cabeza
# seccion
# recortable
# pagina
# seccion
# recortable
# pagina
# cual
# es
# una
# de
# las
# caracteristicas
# que
# te
# hacen
# diferente
# a
# tus
# companeros
# a
# tu
# escuela
# b
# tu
# nombre
# tu
# uniforme
# cuales
# son
# algunas
# algunas
# partes
# caracteristicas
# que
# te
# externas
# de
# ayudan
# a
# conocerte
# tu
# cuerpo
# son
# a
# cuerpo
# edad
# y
# sexo
# a
# cabeza
# tronco
# piernas
# b
# ropa
# estomago
# y
# edad
# y
# brazos
# lengua
# corazon
# y
# b
# lengua
# corazon
# pulmones
# y
# pulmones
# estomago
# y
# cabello
# que
# son
# el
# bano
# en
# que
# momento
# algunas
# diario
# el
# lavado
# del
# dia
# entras
# a
# la
# caracteristicas
# del
# de
# manos
# y
# boca
# escuela
# lugar
# donde
# y
# el
# consumo
# de
# vives
# son
# alimentos
# variados
# y
# agua
# simple
# potable
# a
# manana
# a
# vivienda
# caminos
# comercios
# y
# animales
# a
# actividades
# cotidianas
# b
# noche
# b
# periodicos
# revistas
# tarde
# b
# habitos
# para
# cuidar
# libros
# y
# carteles
# salud
# anuncios
# fotografias
# y
# obligaciones
# de
# higiene
# plantas
# de
# cada
# ano
# el
# de
# septiembre
# que
# se
# celebra
# el
# comienzo
# de
# la
# lucha
# por
# la
# independencia
# demexicoelfinaldelaluchaporlaindependenciademexico
# el
# inicio
# de
# la
# revolucionmexicana
# a
# b
# lugares
# en
# el
# puedes
# localizar
# grafico
# b
# croquis
# a
# esquema
# seccion
# recortable
# pagina
# para
# jugar
# se
# necesita
# un
# dado
# y
# dos
# jugadores
# por
# lo
# menos
# las
# tarjetas
# se
# colocan
# al
# centro
# con
# las
# preguntas
# hacia
# abajo
# por
# turnos
# cada
# jugador
# lanza
# el
# dado
# y
# el
# companero
# toma
# una
# tarjeta
# lee
# la
# pregunta
# y
# si
# contesta
# correctamente
# avanzara
# las
# casillas
# indicadas
# por
# el
# dado
# en
# este
# nivel
# ganara
# el
# primero
# en
# llegar
# a
# la
# casilla
# al
# termino
# de
# cada
# bloque
# obtendras
# las
# tarjetas
# para
# avanzar
# a
# los
# siguientes
# niveles
# seccion
# recortable
